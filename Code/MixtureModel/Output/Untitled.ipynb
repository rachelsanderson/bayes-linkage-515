# %%
from recordlinkage import datasets
import pandas as pd

# %%
(df,index) = datasets.load_krebsregister(block=[1])

# %%
df
# Out:
#              cmp_firstname1  cmp_firstname2  cmp_lastname1  cmp_lastname2  \
# id1   id2
# 49474 54568        0.400000             NaN       0.285714            NaN
# 7134  88023        1.000000             NaN       0.000000            NaN
# 3453  96030        0.285714             NaN       1.000000            NaN
# 1803  44144        1.000000             NaN       0.111111            NaN
# 33475 35225        1.000000             NaN       0.375000            NaN
# 31297 95750        1.000000             NaN       0.142857            NaN
# 6116  47198        1.000000             NaN       0.000000            NaN
# 3565  63731        1.000000             NaN       0.142857            NaN
# 35494 83053        1.000000             NaN       0.111111            NaN
# 8797  73533        0.125000             NaN       0.400000            NaN
# 5007  15438        1.000000             NaN       0.100000            NaN
# ...
